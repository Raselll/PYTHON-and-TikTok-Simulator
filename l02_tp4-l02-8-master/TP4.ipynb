# %% [markdown]
# # Précisions
# N'oubliez pas d'aller consulter les ressources sur les fonctions existentes de pandas, numpy et seaborn qui vous seront utiles lorsque vous réponderez aux questions qui suivent. Voici les sites web concernés à consulter pour les plus récentes versions de chacunes des librairies scientifiques:
# * Pandas: [documentation](https://pandas.pydata.org/docs/)
# * Numpy: [documentation](https://numpy.org/doc/1.21/)
# * Matplotlib: [quelques fonctions plot() pertinentes](https://matplotlib.org/3.5.0/plot_types/index.html)
# * Seaborn: [introduction à seaborn](https://seaborn.pydata.org/introduction.html)
#
# Tout au long du TP, vous pouvez cliquer sur les liens bleus qui vous mèneront vers des ressources encore plus spécifiques pour réaliser chacune des questions.

# %% [markdown]
# # Partie 1: Exploration de la base de données

# %%
#Différents 'imports' nécessaires pour ce TP
import os
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12,6] 
plt.style.use('fivethirtyeight')

# https://www.analyticsvidhya.com/blog/2021/05/pandas-functions-13-most-important/  ==> help you get familiarized with pandas

# %% [markdown]
# ## 1.1 Visualisation des données

# %% [markdown]
# Nous allons travailler avec un fichier .csv (comma separated values), qui contient les 'Happiness score', soit les indicateurs de bonheur de l'année 2020 pour 153 pays du monde. Ces pays sont organisés sur les rangées du Dataframe 'df', une structure de données tabulaire de la librairie pandas. Des paramètres additionnels sont disponibles sur chaque colonnes, qui incluent notamment l'indicateur régional ('Region'), le support social ('Social Support'), le logarithme du produit intérieur brut par capita ('Logged GDP per capita') et plusieurs autres. Il faut en premier visualiser les données en notre possession. Pour ce faire, rouler le code qui suit.

# %%
#Trouve le chemin relatif pour accéder aux données par la suite
path = os.getcwd()
df = pd.read_csv(os.path.join(path, '2020.csv'))

#Précision mise à 2 chiffres après la virgule
pd.set_option("display.precision", 2)

#df.head(x) permet d'afficher les x premières rangées de données, cette fonction vous sera utile pour la suite des choses
#lors de la visualisation de la banque de données modifiée, utilisez la fonction display() au lieu de print() dans le 
#jupyter notebook pour un meilleur affichage
display(df.head(15))
# df.describe()

#La commande ci-dessous vous donne de l'information sur la base de données (dataset), la quantité de valeurs et le type
#de variable utilisée (dtypes, à droite complètement ex:float64 et object est un string)
df.info()
print('\n')
#Pour retrouver un élément de la case 'Country name'
print(f"Le premier élément de la colonne Country name est : {df['Country name'][0]}")

#Nous pouvons aussi retrouver le nombre de régions en utilisant la ligne de code suivante:
df['Region'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country name                       153 non-null    object
#  1   Region                             153 non-null    object
#  2   Happiness score                    153 non-null    float64
#  3   Standard error of happiness score  153 non-null    float64
#  4   Upper Confidence Interval          153 non-null    float64
#  5   Lower Confidence Interval          153 non-null    float64
#  6   Logged GDP per capita              153 non-null    float64
#  7   Social support                     153 non-null    float64
#  8   Healthy life expectancy            153 non-null    float64
#  9   Freedom to make life choices       153 non-null    float64
#  10  Generosity                         153 non-null    float64
#  11  Perceptions of corruption          153 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 14.5+ KB
#
#
# Le premier élément de la colonne Country name est : Finland

# %% [markdown]
# ## Question 1.
# Pour cette question, vous devez retourner les valeurs maximales de 'Happiness score' pour chacune des 10 régions ('Region'). Ainsi la fonction ci-dessous doit retourner un dictionnaire avec ces scores maximaux en ordre décroissant et leurs pays associés en tant que clé. Par exemple: Australia:7.3, Israel:7.21, etc. N'oubliez pas que vous avez accès aux librairies de pandas et numpy qui possèdent plein d'outils pour automatiser un processus de ce genre!

# %% [markdown]
# ### 1.1
# Vous devez en premier lieu créer une fonction simple qui retourne une base de données de la région voulue, soit celle donnée en paramètre à la fonction CreateSubsetPerRegion(). Un exemple de ce qui doit être retourné est présenté ci-dessous:
# ![](attachment:./Capture1.PNG)

# %%
import os
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

def CreateSubsetPerRegion(df, region):
    #TODO Extraire les sous-données par région à l'aide du dataframe pandas ('subset' de données)
    return df[df['Region'] == region]


display(CreateSubsetPerRegion(df,'East Asia'))
display(CreateSubsetPerRegion(df,'Central and Eastern Europe'))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country name</th>
#       <th>Region</th>
#       <th>Happiness score</th>
#       <th>Standard error of happiness score</th>
#       <th>Upper Confidence Interval</th>
#       <th>Lower Confidence Interval</th>
#       <th>Logged GDP per capita</th>
#       <th>Social support</th>
#       <th>Healthy life expectancy</th>
#       <th>Freedom to make life choices</th>
#       <th>Generosity</th>
#       <th>Perceptions of corruption</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18</th>
#       <td>Czech Republic</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.91</td>
#       <td>0.04</td>
#       <td>6.99</td>
#       <td>6.83</td>
#       <td>10.40</td>
#       <td>0.91</td>
#       <td>70.05</td>
#       <td>0.82</td>
#       <td>-0.23</td>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Slovenia</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.36</td>
#       <td>0.04</td>
#       <td>6.45</td>
#       <td>6.28</td>
#       <td>10.39</td>
#       <td>0.94</td>
#       <td>71.10</td>
#       <td>0.94</td>
#       <td>-0.08</td>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Kosovo</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.33</td>
#       <td>0.05</td>
#       <td>6.43</td>
#       <td>6.22</td>
#       <td>9.20</td>
#       <td>0.82</td>
#       <td>63.89</td>
#       <td>0.86</td>
#       <td>0.19</td>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Slovakia</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.28</td>
#       <td>0.04</td>
#       <td>6.36</td>
#       <td>6.20</td>
#       <td>10.35</td>
#       <td>0.92</td>
#       <td>68.91</td>
#       <td>0.75</td>
#       <td>-0.12</td>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Lithuania</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.22</td>
#       <td>0.04</td>
#       <td>6.30</td>
#       <td>6.13</td>
#       <td>10.34</td>
#       <td>0.93</td>
#       <td>67.29</td>
#       <td>0.75</td>
#       <td>-0.22</td>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Poland</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.19</td>
#       <td>0.04</td>
#       <td>6.26</td>
#       <td>6.12</td>
#       <td>10.27</td>
#       <td>0.87</td>
#       <td>69.31</td>
#       <td>0.86</td>
#       <td>-0.21</td>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Romania</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.12</td>
#       <td>0.05</td>
#       <td>6.22</td>
#       <td>6.03</td>
#       <td>10.11</td>
#       <td>0.83</td>
#       <td>67.21</td>
#       <td>0.84</td>
#       <td>-0.20</td>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Estonia</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.02</td>
#       <td>0.04</td>
#       <td>6.09</td>
#       <td>5.95</td>
#       <td>10.34</td>
#       <td>0.93</td>
#       <td>68.60</td>
#       <td>0.88</td>
#       <td>-0.11</td>
#       <td>0.62</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Hungary</td>
#       <td>Central and Eastern Europe</td>
#       <td>6.00</td>
#       <td>0.04</td>
#       <td>6.08</td>
#       <td>5.92</td>
#       <td>10.25</td>
#       <td>0.92</td>
#       <td>67.61</td>
#       <td>0.72</td>
#       <td>-0.19</td>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>Latvia</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.95</td>
#       <td>0.03</td>
#       <td>6.02</td>
#       <td>5.88</td>
#       <td>10.18</td>
#       <td>0.92</td>
#       <td>66.81</td>
#       <td>0.67</td>
#       <td>-0.19</td>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Serbia</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.78</td>
#       <td>0.05</td>
#       <td>5.88</td>
#       <td>5.68</td>
#       <td>9.68</td>
#       <td>0.88</td>
#       <td>68.21</td>
#       <td>0.73</td>
#       <td>-0.07</td>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>Bosnia and Herzegovina</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.67</td>
#       <td>0.05</td>
#       <td>5.77</td>
#       <td>5.58</td>
#       <td>9.46</td>
#       <td>0.83</td>
#       <td>67.81</td>
#       <td>0.65</td>
#       <td>0.10</td>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Montenegro</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.55</td>
#       <td>0.05</td>
#       <td>5.64</td>
#       <td>5.45</td>
#       <td>9.75</td>
#       <td>0.86</td>
#       <td>68.51</td>
#       <td>0.65</td>
#       <td>-0.08</td>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>Croatia</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.50</td>
#       <td>0.04</td>
#       <td>5.58</td>
#       <td>5.43</td>
#       <td>10.07</td>
#       <td>0.87</td>
#       <td>70.21</td>
#       <td>0.71</td>
#       <td>-0.13</td>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>Macedonia</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.16</td>
#       <td>0.05</td>
#       <td>5.25</td>
#       <td>5.07</td>
#       <td>9.51</td>
#       <td>0.82</td>
#       <td>67.50</td>
#       <td>0.74</td>
#       <td>-0.02</td>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>Bulgaria</td>
#       <td>Central and Eastern Europe</td>
#       <td>5.10</td>
#       <td>0.04</td>
#       <td>5.19</td>
#       <td>5.01</td>
#       <td>9.87</td>
#       <td>0.94</td>
#       <td>66.80</td>
#       <td>0.75</td>
#       <td>-0.14</td>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>Albania</td>
#       <td>Central and Eastern Europe</td>
#       <td>4.88</td>
#       <td>0.06</td>
#       <td>4.99</td>
#       <td>4.77</td>
#       <td>9.42</td>
#       <td>0.67</td>
#       <td>68.71</td>
#       <td>0.78</td>
#       <td>-0.04</td>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 1.2
# Il faut maintenant retourner le dictionnaire ordonné en ordre décroissant du pays associé à la valeur maximale par région tel qu'indiqué dans la question 1. À nouveau, n'oubliez pas que vous avez accès à des librairies qui automatisent ces processus plus facilement.

# %%
import operator
import os
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

def ClassMaxScorePerRegion(df):
    #TODO Trouver les régions pour en faire une liste (https://numpy.org/doc/stable/reference/generated/numpy.unique.html)
    liste_regions = np.unique(df[['Region']])

    #TODO Pour chacune des régions, trouves les valeurs maximales et le pays associé
    liste_max_values = []
    liste_indexes = []
    liste_countries = []
    liste = []
    dictionnaire = {}
    for i in liste_regions:
      max_value = (CreateSubsetPerRegion(df,i))['Happiness score'].max()
      

      liste_max_values.append(max_value)
      indexes = CreateSubsetPerRegion(df,i)[CreateSubsetPerRegion(df,i)['Happiness score'] == max_value].index.values
      liste_indexes.append(indexes)
      country = CreateSubsetPerRegion(df,i).loc[indexes , 'Country name']
      liste.append(country)
    for element in liste:
      liste_countries.append(''.join(list(element.values)))
      
    for j in range(len(liste)):
      dictionnaire[liste_countries[j]] = liste_max_values[j]  

    #TODO Création d'un dictionnaire en ordre décroissant des valeurs de 'Happiness score'   
    sorted_dict = dict(sorted(dictionnaire.items(),key = operator.itemgetter(1),reverse = True))
    

    return sorted_dict

  
   
ClassMaxScorePerRegion(df)
# Out:
# {'Finland': 7.808700085,
#  'New Zealand': 7.299600124,
#  'Israel': 7.128600121,
#  'Costa Rica': 7.121399879,
#  'Czech Republic': 6.910900116,
#  'Taiwan': 6.45539999,
#  'Singapore': 6.377099991,
#  'Uzbekistan': 6.257599831,
#  'Mauritius': 6.101299763,
#  'Pakistan': 5.69329977}

# %% [markdown]
# ## Question 2
# Nous allons maintenant rajouter les données de 2016 afin de les comparer à celles de 2020. Tout d'abord, utilisez ImportNewData() pour importer cette nouvelle base de données nommée 2016.csv. Avec les pays ayant obtenu les scores maximaux de 'Happiness score' par région, le but est de tracer leur évolution entre 2016 à 2020. L'évolution doit être représentée de la plus petite différence à la plus grande. Pour ce faire, vous allez en premier lieu trouver les différences avec la fonction FindDifferences() qui retourne un dictionnaire en ordre croissant de ces différences. Par la suite, vous tracerez ces différences par pays. Voici un exemple de graphique à barre voulu à réaliser avec la fonction PlotComparison(), ce ne sont pas nécessairement les pays voulus. Vous pouvez vous renseigner sur la fonction [plt.bar](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html) de matplotlib.
# ![](attachment:./Capture2.PNG)

# %% [markdown]
# ### 2.1
# Importation des données de l'année 2016

# %%
def ImportNewData(file):
    #TODO Import de la base de données pour 2016
    df_2016 = pd.read_csv(file)
    #TODO Afficher les 10 premières rangées de la base de données de 2016
    path = os.getcwd()

    return df_2016.head(10)
ImportNewData('2016.csv')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country name</th>
#       <th>Region</th>
#       <th>Happiness score</th>
#       <th>Lower Confidence Interval</th>
#       <th>Upper Confidence Interval</th>
#       <th>Economy (GDP per Capita)</th>
#       <th>Family</th>
#       <th>Healthy life expectancy</th>
#       <th>Freedom</th>
#       <th>Trust (Government Corruption)</th>
#       <th>Generosity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Denmark</td>
#       <td>Western Europe</td>
#       <td>7.53</td>
#       <td>7.46</td>
#       <td>7.59</td>
#       <td>1.44</td>
#       <td>1.16</td>
#       <td>79.50</td>
#       <td>0.58</td>
#       <td>0.44</td>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Switzerland</td>
#       <td>Western Europe</td>
#       <td>7.51</td>
#       <td>7.43</td>
#       <td>7.59</td>
#       <td>1.53</td>
#       <td>1.15</td>
#       <td>86.30</td>
#       <td>0.59</td>
#       <td>0.41</td>
#       <td>0.28</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Iceland</td>
#       <td>Western Europe</td>
#       <td>7.50</td>
#       <td>7.33</td>
#       <td>7.67</td>
#       <td>1.43</td>
#       <td>1.18</td>
#       <td>86.73</td>
#       <td>0.57</td>
#       <td>0.15</td>
#       <td>0.48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Norway</td>
#       <td>Western Europe</td>
#       <td>7.50</td>
#       <td>7.42</td>
#       <td>7.58</td>
#       <td>1.58</td>
#       <td>1.13</td>
#       <td>79.58</td>
#       <td>0.60</td>
#       <td>0.36</td>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Finland</td>
#       <td>Western Europe</td>
#       <td>7.41</td>
#       <td>7.35</td>
#       <td>7.47</td>
#       <td>1.41</td>
#       <td>1.13</td>
#       <td>81.09</td>
#       <td>0.57</td>
#       <td>0.41</td>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Canada</td>
#       <td>North America</td>
#       <td>7.40</td>
#       <td>7.33</td>
#       <td>7.47</td>
#       <td>1.44</td>
#       <td>1.10</td>
#       <td>82.76</td>
#       <td>0.57</td>
#       <td>0.31</td>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Netherlands</td>
#       <td>Western Europe</td>
#       <td>7.34</td>
#       <td>7.28</td>
#       <td>7.39</td>
#       <td>1.46</td>
#       <td>1.03</td>
#       <td>81.23</td>
#       <td>0.55</td>
#       <td>0.30</td>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>New Zealand</td>
#       <td>Australia and New Zealand</td>
#       <td>7.33</td>
#       <td>7.26</td>
#       <td>7.40</td>
#       <td>1.36</td>
#       <td>1.17</td>
#       <td>83.10</td>
#       <td>0.58</td>
#       <td>0.42</td>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Australia</td>
#       <td>Australia and New Zealand</td>
#       <td>7.31</td>
#       <td>7.24</td>
#       <td>7.38</td>
#       <td>1.44</td>
#       <td>1.10</td>
#       <td>85.12</td>
#       <td>0.57</td>
#       <td>0.32</td>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Sweden</td>
#       <td>Western Europe</td>
#       <td>7.29</td>
#       <td>7.23</td>
#       <td>7.36</td>
#       <td>1.45</td>
#       <td>1.09</td>
#       <td>83.12</td>
#       <td>0.58</td>
#       <td>0.41</td>
#       <td>0.38</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2.2
# Implémentation des fonctions pour illustrer les différences pour les 10 pays concernés entre 2016 et 2020

# %%
def FindDifferences(df_1,df_2):
    #TODO Reprendre les valeurs obtenues précédemment du pays avec le score maximal par région
    df_1 = ClassMaxScorePerRegion(df)
    df_2 = df_2016
    pays_max_2020 = []
    liste_happiness_score_2016 = []
    dictionnaire_differences = {}
    liste = []
    for i in df_1:
        pays_max_2020.append(i)
    for j in pays_max_2020:
        liste_happiness_score_2016.append(df_2.loc[df_2['Country name'] == j , 'Happiness score'].values)

    #TODO Retourner un dictionnaire des différences en ordre croissant
    for i in range(len(pays_max_2020)):
        dictionnaire_differences[pays_max_2020[i]] = df_1[pays_max_2020[i]] - float(liste_happiness_score_2016[i])
    
    return dict(sorted(dictionnaire_differences.items(),key = operator.itemgetter(1)))

def PlotComparison(sorted_dict):
    #TODO Faire un bar plot de ces différences
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    ax.set_title('Différence entre 2016 à 2020 des scores de bonheur en fonction du pays'  , fontweight = 'bold')
    ax.set_ylabel('Différence de score de bonheur' , size = 18)
    ax.set_xlabel('Pays' , size = 18)
    plt.xticks(rotation=90)
    differences = (sorted_dict.values())

    countries = list(sorted_dict.keys())
    ax.bar(countries , differences)

    
    plt.show()
    
sorted_dict = FindDifferences(df, df_2016)
PlotComparison(sorted_dict)
#FindDifferences(df_1=df , df_2= ImportNewData('2016.csv'))
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 36 in <module>
# NameError: name 'df_2016' is not defined

# %% [markdown]
# ## Question 3
# Seaborn est une librairie qui permet de plus facilement tracer des graphiques complexes. Souvent, des [subplot](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html) via matplotlib sont utilisés afin d'afficher plusieurs graphiques dans la même figure à des fins de comparaisons. Nous nous intéresserons maintenant à deux paramètres particuliers:
# 1. Healthy life expectancy
# 2. Happiness score
#
# Vous devez comparer pour les deux années 2016 et 2020 ces deux paramètres pour un pays et une région donnés en paramètre de la fonction PlotDistributions() ci-dessous. Pour le premier paramètre, vous utiliserez [sns.displot](https://seaborn.pydata.org/generated/seaborn.distplot.html) et pour le second paramètre, vous ferez usage des fonctionnalités de pandas pour le traçage avec [boxplot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html). Assurez vous également que le pays donné en paramètre de la fonction à écrire correspond à la région associée avant de tracer les graphiques voulus. Voici un exemple d'affichage:
# ![](attachment:./Capture3.PNG)
#
#
# En cas de région et de pays qui ne correspondent pas, vous devez retourner:
# ![](attachment:./Capture4.PNG)

# %%
text_1 = "value"

# %%
# *** CE CODE EST NECESSAIRE POUR LE BON FONCTIONNEMENT DU CODE DES 4 GRAPHES, CAR LE return df_2016 est reappaler ***

def ImportNewData(file):
    #TODO Import de la base de données pour 2016
    df_2016 = pd.read_csv(file)
    #TODO Afficher les 10 premières rangées de la base de données de 2016
    path = os.getcwd()
    #ClassMaxScorePerRegion(file)

    

    
    
    #return ClassMaxScorePerRegion(file)
    return df_2016
#ImportNewData('2016.csv')

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from typing import List

path = os.getcwd()
df = pd.read_csv(os.path.join(path, '2020.csv'))

def PlotDistributions(df_1, df_2, region, country):
    #TODO  Vérifier si le pays fait partie de la région donnée sinon afficher le message indiqué plus haut

    if df_2['Region'][df_2['Country name']==country].to_numpy()[0] == region:


    #TODO Utiliser sns.displot et df.boxplot pour visualiser les deux paramètres demandés
    #fig, axes = plt.subplots(2,2)
    
        # Graph 1
        # wow1 = sns.displot(data=df_1, x='Healthy life expectancy', kde = True, color = 'skyblue', lw =4)
        # wow1.set_titles('2016')
        # #plt.show(wow1)
        # # Graph 2
        # wow2 = sns.displot(data=df_2, x='Healthy life expectancy', kde = True, color = 'skyblue', lw =4)
        # wow2.set_titles('2020')
        # #plt.show(wow2)
        # # Graph 3
        # boxplot1 = df_2016.boxplot(column=['Happiness score'])
        # #plt.show(boxplot1)
        # #Graph 4
        # boxplot2 = df.boxplot(column=['Happiness score'])
        # #plt.show(boxplot2)

                  
        fig,axes = plt.subplots(2, 2, figsize = (14,10))
        sns.histplot(ax = axes[0,0], data = df_1, x='Healthy life expectancy',kde = True, color = 'skyblue', lw =4)
        sns.histplot(ax = axes[0,1], data = df_2, x='Healthy life expectancy',kde = True, color = 'skyblue', lw =4)
        df_1.boxplot(column=['Happiness score'], ax = axes[1,0])
        df_2.boxplot(column=['Happiness score'], ax = axes[1,1])
        #sns.boxplot(ax = axes[1,1], data = df_2.boxplot(column=['Happiness score']))
        plt.suptitle(f'Comparaison de deux parametres en 2016 et 2020 pour {country}')
    
    else:
        print(f'Le pays donne soit {country} ne correspond pas a la region {region}')






#TODO Si région et pays ne correspondent pas retourner le message indiqué ci-haut
    # else:
    #     return ''
    
df_2016= ImportNewData(r'2016.csv')
df= ImportNewData(r'2020.csv')

PlotDistributions(df_2016, df, 'North America and ANZ', 'Canada')
PlotDistributions(df_2016, df, 'Western Europe', 'Taiwan')
# Out:
# Le pays donne soit Taiwan ne correspond pas a la region Western Europe

# %% [markdown]
# ## Question 4
# En se concentrant maintenant à nouveau sur les données de **2020**, nous allons essayer de trouver le paramètre le plus corrélé avec le score de bonheur 'Happiness score'. Nous allons prendre des paramètres spécifiques à analyser:
# 1. Happiness score
# 2. Logged GDP per capita
# 3. Social support
# 4. Healthy life expectancy
# 5. Freedom to make life choices
# 6. Generosity
# 7. Perceptions of corruption
#
# Utilisez un [sns.heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) afin de visualiser ces [corrélations](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html). Votre heatmap de corrélation devrait ressembler à ce qui est présenté ci-dessous. Attention, ce qui est affiché n'est pas exactement ce que vous allez obtenir puisque ce ne sont pas les même données utilisées. L'exemple n'est qu'indicatif pour la ressemblance visuelle à obtenir.
# ![](attachment:./Capture5.PNG)
#
# Pour ce faire, vous allez écrire la fonction FindCorrelations(). En plus d'afficher le heatmap, cette fonction retourne la valeur maximale de corrélation avec le score de bonheur en considérant un paramètre différent de lui-même. En effet, comme vous pouvez le voir à la figure ci-haut le paramètre 'Happiness score' est toujours corrélé à 100% avec lui-même. Nous nous intéresserons donc plutôt à la deuxième valeur de corrélation la plus élevée et le paramètre qui lui est associé. L'affichage final ressemble à ceci et le coefficient de corrélation doit être arrondi au centième près:
# ![](attachment:./Capture7.PNG)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import os

# Réajuste le fond d'affichage à blanc

matplotlib.rcParams['figure.facecolor'] = 'w'

def FindCorrelations(df):
    df = pd.read_csv('2020.csv')
    #TODO Sélectionner les 7 paramètres à étudier
    columns = (df['Happiness score'], df['Logged GDP per capita'], df['Social support'], 
               df['Healthy life expectancy'], df['Freedom to make life choices'], df['Generosity'],
               df['Perceptions of corruption'])
    
    data = pd.read_csv('2020.csv')
    dataplot = sb.heatmap(data.corr(), center = 0, cmap = 'coolwarm', annot = True, vmin = 0, vmax = 1)
    plt.title("Tableau de correlation entre plusieurs parametres etudies en 2020 ", fontsize =20)
    #mp.show()

    max_cor = data.corr(). iat[0,4]
    data2 = data.corr().columns[1]

    #plt.show()
    return max_cor, data2

max_cor, data2 = FindCorrelations(df)
FindCorrelations(df)

#TODO Afficher la phrase indiquant le coefficient de corrélation le plus élevé avec le paramètre 'Happiness score'

affichage = 'Le parametre avec un coefficient de le plus eleve avec Happiness score est ' + str(data2) + ' avec ' + str(max_cor) + ' .'
print(affichage)
# Out:
# Le parametre avec un coefficient de le plus eleve avec Happiness score est Standard error of happiness score avec 0.7753744007526835 .

# %% [markdown]
# ## Tests à rouler
# La cellule ci-dessous vous permet de tester certaines questions lorsqu'il s'agissait de retourner un print ou bien des dictionnaires en valeurs de retour. Les affichage de graphiques ainsi que les Dataframes retournés ne seront pas testés.

# %%
import unittest
import os
import sys
class TestQ1(unittest.TestCase):
    result = {'Finland': 7.808700085, 'New Zealand': 7.2996001239999995, 'Israel': 7.128600121, 'Costa Rica': 7.121399879, 'Czech Republic': 6.9109001160000005, 'Taiwan': 6.45539999, 'Singapore': 6.377099991000001, 'Uzbekistan': 6.257599831, 'Mauritius': 6.101299762999999, 'Pakistan': 5.69329977}

    def test1_real_value(self):
        self.assertDictEqual(ClassMaxScorePerRegion(df), self.result)


class TestQ2(unittest.TestCase):
    def test2_find_differences(self):
        sorted_val = {'Singapore': -0.3619000089999993, 'Israel': -0.1383998790000005, 'New Zealand': -0.03439987600000016, 'Costa Rica': 0.03439987899999952, 'Taiwan': 0.07639999000000053, 'Uzbekistan': 0.2705998310000002, 'Czech Republic': 0.31490011600000045, 'Finland': 0.39570008500000053, 'Mauritius': 0.4532997629999995, 'Pakistan': 0.5612997699999998}
        self.assertDictEqual(FindDifferences(df, df_2016), sorted_val)


class TestQ3(unittest.TestCase):
    

    def test3_plot_distributions(self):
        wanted = 'Le pays donné soit Taiwan ne correspond pas à la région Western Europe'
        self.assertEqual(PlotDistributions(df_2016, df, 'Western Europe', 'Taiwan'), wanted)


class TestQ4(unittest.TestCase):
     def test41_find_correlations(self):
        wanted = 'Le paramètre avec un coefficient de corrélation le plus élévé avec Happiness score est Logged GDP per capita avec 0.78'
        self.assertEqual(affichage, wanted)
        
res = unittest.main(argv=[''], verbosity=3, exit=False)
# if we want our notebook to stop processing due to failures, we need a cell itself to fail
assert len(res.result.failures) == 0
# Out:
# Le pays donne soit Taiwan ne correspond pas a la region Western Europe
# test1_real_value (__main__.TestQ1) ... FAIL
# test2_find_differences (__main__.TestQ2) ... FAIL
# test3_plot_distributions (__main__.TestQ3) ... FAIL
# test41_find_correlations (__main__.TestQ4) ... FAIL
#
# ======================================================================
# FAIL: test1_real_value (__main__.TestQ1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-32-58aff3569952>", line 8, in test1_real_value
#     self.assertDictEqual(ClassMaxScorePerRegion(df), self.result)
# AssertionError: {'Fin[40 chars]600124, 'Israel': 7.128600121, 'Costa Rica': 7[162 chars]9977} != {'Fin[40 chars]6001239999995, 'Israel': 7.128600121, 'Costa R[188 chars]9977}
# Diff is 646 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test2_find_differences (__main__.TestQ2)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-32-58aff3569952>", line 14, in test2_find_differences
#     self.assertDictEqual(FindDifferences(df, df_2016), sorted_val)
# AssertionError: {'Sin[15 chars]9000090000002, 'Israel': -0.1383998790000005, [268 chars]0006} != {'Sin[15 chars]9000089999993, 'Israel': -0.1383998790000005, [267 chars]9998}
# Diff is 1075 characters long. Set self.maxDiff to None to see it.
#
# ======================================================================
# FAIL: test3_plot_distributions (__main__.TestQ3)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-32-58aff3569952>", line 22, in test3_plot_distributions
#     self.assertEqual(PlotDistributions(df_2016, df, 'Western Europe', 'Taiwan'), wanted)
# AssertionError: None != 'Le pays donné soit Taiwan ne correspond pas à la région Western Europe'
#
# ======================================================================
# FAIL: test41_find_correlations (__main__.TestQ4)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-32-58aff3569952>", line 28, in test41_find_correlations
#     self.assertEqual(affichage, wanted)
# AssertionError: ('Le parametre avec un coefficient de  le[109 chars]' .') != 'Le paramètre avec un coefficient de corr[74 chars]0.78'
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.084s
#
# FAILED (failures=4)
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 32 in <module>
# AssertionError:

# %% [markdown]
# ## Suite...
# Rendez-vous à la partie 3 que vous pouvez retrouver dans le fichier tests.py du github et dont les instructions sont dans le readme.
